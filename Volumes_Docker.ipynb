# %%
# %%writefile Dockerfile
# # Utilisation de l'image de base
# FROM tiangolo/uvicorn-gunicorn-fastapi:python3.8
#
# # Répertoire de travail dans le conteneur
# WORKDIR /app
#
# # Copie des fichiers nécessaires
# COPY requirements.txt ./
# RUN pip install --no-cache-dir -r requirements.txt
#
# COPY ./app /app
#
# # Commande pour démarrer l'application
# CMD ["uvicorn", "app.app:app", "--host", "0.0.0.0", "--port", "80"]
# Out:
# Overwriting Dockerfile

# %%
import os

# Créer le dossier 'app' s'il n'existe pas déjà
os.makedirs('app', exist_ok=True)

# %%
# %%writefile app/app.py
from fastapi import FastAPI

app = FastAPI()

@app.get("/")
async def read_root():
    return {"Hello": "World"}
# Out:
# Overwriting app/app.py

# %%
# %%writefile requirements.txt
# fastapi==0.68.1
# uvicorn==0.15.0
# Out:
# Overwriting requirements.txt

# %%
# !docker build -t myimage .
# Out:
# [+] Building 0.0s (0/1)                                          docker:default
# [+] Building 0.2s (1/2)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 418B                                       0.0s
#  => [internal] load metadata for docker.io/tiangolo/uvicorn-gunicorn-fast  0.2s
# [+] Building 0.3s (1/2)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 418B                                       0.0s
#  => [internal] load metadata for docker.io/tiangolo/uvicorn-gunicorn-fast  0.3s
# [+] Building 0.5s (1/2)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 418B                                       0.0s
# ...

# %%
# !docker run -d --name mycontainer -p 8000:80 myimage
# Out:
# f3f1c94e0e39b611d789e4a7bdf21593727f82680d519797f5d6c925d4a59e63

# %%
# !docker ps -a
# Out:
# CONTAINER ID   IMAGE          COMMAND                  CREATED             STATUS                      PORTS     NAMES
# f3f1c94e0e39   myimage        "uvicorn app.app:app…"   6 seconds ago       Exited (1) 5 seconds ago              mycontainer
# 7b2f8bfc7b24   fastapi-demo   "uvicorn main:app --…"   50 minutes ago      Exited (0) 50 minutes ago             gallant_keller
# d4f12e031648   fastapi-demo   "uvicorn main:app --…"   54 minutes ago      Exited (0) 52 minutes ago             jovial_banzai
# c53f6866d51d   c848e852775c   "uvicorn main:app --…"   About an hour ago   Exited (0) 56 minutes ago             compassionate_roentgen

# %%
# !docker rm -f mycontainer
# Out:
# mycontainer

# %%
# !docker run -d --name mycontainer -p 8000:80 myimage
# Out:
# ccafb30c31195a6ac38e8c586ed59a40135f1de2a13518c667fb600fe9b0cfd2

# %%
# !docker ps -a
# Out:
# CONTAINER ID   IMAGE          COMMAND                  CREATED              STATUS                          PORTS     NAMES
# ccafb30c3119   myimage        "uvicorn app.app:app…"   About a minute ago   Exited (1) About a minute ago             mycontainer
# 7b2f8bfc7b24   fastapi-demo   "uvicorn main:app --…"   36 minutes ago       Exited (0) 36 minutes ago                 gallant_keller
# d4f12e031648   fastapi-demo   "uvicorn main:app --…"   40 minutes ago       Exited (0) 38 minutes ago                 jovial_banzai
# c53f6866d51d   c848e852775c   "uvicorn main:app --…"   53 minutes ago       Exited (0) 43 minutes ago                 compassionate_roentgen

# %%
# !docker build --no-cache -t myimage .
# Out:
# [+] Building 0.0s (0/1)                                          docker:default
# [+] Building 0.2s (1/2)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 370B                                       0.0s
#  => [internal] load metadata for docker.io/tiangolo/uvicorn-gunicorn-fast  0.1s
# [+] Building 0.3s (1/2)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 370B                                       0.0s
#  => [internal] load metadata for docker.io/tiangolo/uvicorn-gunicorn-fast  0.3s
# [+] Building 0.5s (1/2)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 370B                                       0.0s
# ...

# %%
# !docker build -t myimage .
# Out:
# [+] Building 0.0s (0/1)                                          docker:default
# [+] Building 0.2s (1/2)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 524B                                       0.0s
#  => [internal] load metadata for docker.io/tiangolo/uvicorn-gunicorn-fast  0.2s
# [+] Building 0.3s (1/2)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 524B                                       0.0s
#  => [internal] load metadata for docker.io/tiangolo/uvicorn-gunicorn-fast  0.3s
# [+] Building 0.5s (1/2)                                          docker:default
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 524B                                       0.0s
# ...

# %%
# !docker run -d --name mycontainer -p 8000:80 myimage
# Out:
# 82b63e8c8b2cba71e6f560be64957b302cc0adf1e2b4ac3aaf93d08606ab81ae

# %%
# !docker rm mycontainer
# Out:
# mycontainer

# %%
# !docker ps -a
# Out:
# CONTAINER ID   IMAGE          COMMAND                  CREATED             STATUS                              PORTS     NAMES
# 82b63e8c8b2c   myimage        "uvicorn app.app:app…"   3 seconds ago       Exited (1) Less than a second ago             mycontainer
# 7b2f8bfc7b24   fastapi-demo   "uvicorn main:app --…"   46 minutes ago      Exited (0) 46 minutes ago                     gallant_keller
# d4f12e031648   fastapi-demo   "uvicorn main:app --…"   51 minutes ago      Exited (0) 48 minutes ago                     jovial_banzai
# c53f6866d51d   c848e852775c   "uvicorn main:app --…"   About an hour ago   Exited (0) 53 minutes ago                     compassionate_roentgen

# %%
# !docker run -it --rm myimage uvicorn app.app:app --host 0.0.0.0 --port 80
# Out:
# ERROR:    Error loading ASGI app. Could not import module "app.app".

# %%
# !git add Volumes_Docker.ipynb && git commit -m "Docker Volume" && git push origin main
# Out:
# [main 7877ed1] Docker Volume
#  1 file changed, 1484 insertions(+)
#  create mode 100644 Volumes_Docker.ipynb
# Énumération des objets: 4, fait.
# Décompte des objets: 100% (4/4), fait.
# Compression par delta en utilisant jusqu'à 2 fils d'exécution
# Compression des objets: 100% (3/3), fait.
# Écriture des objets: 100% (3/3), 7.57 Kio | 2.52 Mio/s, fait.
# Total 3 (delta 1), réutilisés 0 (delta 0), réutilisés du pack 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To github.com:Cherycoco/Python.git
#    3d36035..7877ed1  main -> main
