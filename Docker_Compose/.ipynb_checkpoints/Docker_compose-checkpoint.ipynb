# %%
import os

# Définir le chemin
base_path = 'Docker_Compose/app'  # Assurez-vous que c'est le bon nom de dossier
os.makedirs(base_path, exist_ok=True)

# Créer le fichier docker-compose.yml
with open('Docker_Compose/docker-compose.yml', 'w') as f:
    f.write("""version: '3'

services:
  web:
    build: ./app
    ports:
      - '5000:5000'
    volumes:
      - ./app:/app
    depends_on:
      - redis-container

  redis-container:
    image: redis
""")

# Créer le Dockerfile
with open(os.path.join(base_path, 'Dockerfile'), 'w') as f:
    f.write("""FROM python:3.8
WORKDIR /app
COPY . .
RUN pip install -r requirements.txt
CMD ["python", "app.py"]
""")

# Créer le fichier requirements.txt
with open(os.path.join(base_path, 'requirements.txt'), 'w') as f:
    f.write("""flask
redis
""")

# Créer le fichier app.py
with open(os.path.join(base_path, 'app.py'), 'w') as f:
    f.write("""from flask import Flask
from redis import Redis

app = Flask(__name__)
redis = Redis(host='redis-container', port=6379)

@app.route('/')
def hello():
    redis.incr('hits')
    return 'Cette page a été vue {} fois.'.format(redis.get('hits'))

if __name__ == '__main__':
    app.run(host='0.0.0.0', port=5000, debug=True)
""")

# %%
# Changer de répertoire vers Docker_Compose
# !cd Docker_Compose

# Construire et démarrer l'application avec Docker Compose
# !docker-compose up --build
# Out:
# /bin/bash: ligne 1 : cd: Docker_Compose: Aucun fichier ou dossier de ce nom
# [+] Building 0.0s (0/1)
# [+] Building 0.2s (1/2)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 136B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.8              0.1s
# [+] Building 0.3s (1/2)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 136B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.8              0.3s
# [+] Building 0.5s (1/2)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 136B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.8              0.4s
# [+] Building 0.6s (1/2)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 136B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.8              0.6s
# [+] Building 0.8s (1/2)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 136B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.8              0.7s
# [+] Building 0.9s (1/2)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 136B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.8              0.9s
# [+] Building 1.0s (2/2)
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 136B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.8              1.0s
# [+] Building 1.1s (9/9) FINISHED
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 136B                                       0.0s
#  => [internal] load metadata for docker.io/library/python:3.8              1.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/4] FROM docker.io/library/python:3.8@sha256:7e95ab14a94834b6e3b339  0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 553B                                          0.0s
#  => CACHED [2/4] WORKDIR /app                                              0.0s
#  => CACHED [3/4] COPY . .                                                  0.0s
#  => CACHED [4/4] RUN pip install -r requirements.txt                       0.0s
#  => exporting to image                                                     0.0s
#  => => exporting layers                                                    0.0s
#  => => writing image sha256:41ddcdb354626b9a87640f632e2546f54747adb103949  0.0s
#  => => naming to docker.io/library/docker_compose-web                      0.0s
# [+] Running 2/0
#  ⠿ Container docker_compose-redis-container-1  Created                     0.0s
#  ⠿ Container docker_compose-web-1              Created                     0.0s
# Attaching to docker_compose-redis-container-1, docker_compose-web-1
# docker_compose-redis-container-1  | 1:C 24 Sep 2024 10:23:16.318 # WARNING Memory overcommit must be enabled! Without it, a background save or replication may fail under low memory condition. Being disabled, it can also cause failures without low memory condition, see https://github.com/jemalloc/jemalloc/issues/1328. To fix this issue add 'vm.overcommit_memory = 1' to /etc/sysctl.conf and then reboot or run the command 'sysctl vm.overcommit_memory=1' for this to take effect.
# docker_compose-redis-container-1  | 1:C 24 Sep 2024 10:23:16.319 * oO0OoO0OoO0Oo Redis is starting oO0OoO0OoO0Oo
# docker_compose-redis-container-1  | 1:C 24 Sep 2024 10:23:16.319 * Redis version=7.4.0, bits=64, commit=00000000, modified=0, pid=1, just started
# docker_compose-redis-container-1  | 1:C 24 Sep 2024 10:23:16.319 # Warning: no config file specified, using the default config. In order to specify a config file use redis-server /path/to/redis.conf
# docker_compose-redis-container-1  | 1:M 24 Sep 2024 10:23:16.320 * monotonic clock: POSIX clock_gettime
# docker_compose-redis-container-1  | 1:M 24 Sep 2024 10:23:16.321 * Running mode=standalone, port=6379.
# docker_compose-redis-container-1  | 1:M 24 Sep 2024 10:23:16.321 * Server initialized
# docker_compose-redis-container-1  | 1:M 24 Sep 2024 10:23:16.322 * Loading RDB produced by version 7.4.0
# docker_compose-redis-container-1  | 1:M 24 Sep 2024 10:23:16.322 * RDB age 2677 seconds
# docker_compose-redis-container-1  | 1:M 24 Sep 2024 10:23:16.322 * RDB memory usage when created 0.97 Mb
# docker_compose-redis-container-1  | 1:M 24 Sep 2024 10:23:16.322 * Done loading RDB, keys loaded: 1, keys expired: 0.
# docker_compose-redis-container-1  | 1:M 24 Sep 2024 10:23:16.322 * DB loaded from disk: 0.000 seconds
# docker_compose-redis-container-1  | 1:M 24 Sep 2024 10:23:16.322 * Ready to accept connections tcp
# docker_compose-web-1              |  * Serving Flask app 'app'
# docker_compose-web-1              |  * Debug mode: on
# docker_compose-web-1              | WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
# docker_compose-web-1              |  * Running on all addresses (0.0.0.0)
# docker_compose-web-1              |  * Running on http://127.0.0.1:5000
# docker_compose-web-1              |  * Running on http://172.18.0.3:5000
# docker_compose-web-1              | Press CTRL+C to quit
# docker_compose-web-1              |  * Restarting with stat
# docker_compose-web-1              |  * Debugger is active!
# docker_compose-web-1              |  * Debugger PIN: 396-281-946
# docker_compose-web-1              | 172.18.0.1 - - [24/Sep/2024 10:23:20] "GET / HTTP/1.1" 200 -

# %%
# Arrêter et supprimer les conteneurs
# !cd Docker_Compose; docker-compose down

# %%
# !git add Docker_compose.ipynb && git commit -m "Docker Compose" && git push origin main
